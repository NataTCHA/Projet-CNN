# %% [markdown]
# **CNN avec Spectrogramme sur corpus glides**

# %% [markdown]
# Afin de pouvoir comparer équitablement les deux entrées ( spectro vs modulation ), les deux modèles sont identiques.
#
#
# Importation des bibliothèques

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import BatchNormalization
from keras.layers import ZeroPadding2D, Conv2D
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import random
import numpy as np
import glob
import csv
from sklearn.metrics import confusion_matrix
# Out:
# WARNING:tensorflow:From C:\Users\Natou\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# Importation du corpus train et test pour la classe malade et sain

# %%
list_malade = glob.glob('malade_spectro_glides/test/*')
list_ok = glob.glob('sain_spectro_glides/test/*')
img_rows=28
img_cols=28
x_test = []  
y_test = []

dico = {'malade': 0, 'non_malade': 1}
#test
for path in list_malade:
    x=cv2.imread(path,0).astype(np.uint8)
    x=cv2.resize(x,(img_rows,img_cols))
    y = dico['malade']
    x_test.append(x)
    y_test.append(y)

for path in list_ok:
    x=cv2.imread(path,0).astype(np.uint8)
    x=cv2.resize(x,(img_rows,img_cols))
    y = dico['non_malade']
    x_test.append(x)
    y_test.append(y)


#train

list_malade_train = glob.glob('malade_spectro_glides/train/*')
list_ok_train = glob.glob('sain_spectro_glides/train/*')

x_train = []
y_train = []


for path in list_malade_train:
    x = cv2.imread(path, 0).astype(np.uint8)
    x = cv2.resize(x, (img_rows, img_cols))
    y = dico['malade']
    x_train.append(x)
    y_train.append(y)

for path in list_ok_train:
    x = cv2.imread(path, 0).astype(np.uint8)
    x = cv2.resize(x, (img_rows, img_cols))
    y = dico['non_malade']
    x_train.append(x)
    y_train.append(y)

x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)
x_train = x_train.reshape(-1, img_rows, img_cols, 1)
x_test = x_test.reshape(-1, img_rows, img_cols, 1)
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %% [markdown]
# Définition de la fonction sheduler permettant de faire évoluer le taux d'apprentissage en fonction du nombre d'epoch

# %%
def lr_schedule(epoch):
    lr = 1e-4
    if epoch > 30:
        lr *= 0.1
    elif epoch > 20:
        lr *= 0.5
    return lr

# %% [markdown]
# Initialisation du modèle

# %%
model = Sequential()
model.add(Conv2D(512, kernel_size=(2, 2), activation='relu', input_shape=(img_rows, img_cols, 1), padding='same'))
model.add(BatchNormalization())
value_top = 0
value_bottom = 0
value_left = 0
value_right = 0
model.add(ZeroPadding2D(padding=((value_top, value_bottom), (value_left, value_right))))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(256, (2, 2), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, (2, 2), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(2, activation='sigmoid'))
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Natou\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Natou\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 512)       2560
#
#  batch_normalization (Batch  (None, 28, 28, 512)       2048
#  Normalization)
#
#  zero_padding2d (ZeroPaddin  (None, 28, 28, 512)       0
#  g2D)
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 512)       0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 256)       524544
#
#  batch_normalization_1 (Bat  (None, 14, 14, 256)       1024
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 256)         0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 128)         131200
#
#  batch_normalization_2 (Bat  (None, 7, 7, 128)         512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 3, 3, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dropout (Dropout)           (None, 1152)              0
#
#  dense (Dense)               (None, 512)               590336
#
#  batch_normalization_3 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_4 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dense_2 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 1387138 (5.29 MB)
# Trainable params: 1383810 (5.28 MB)
# Non-trainable params: 3328 (13.00 KB)
# _________________________________________________________________

# %% [markdown]
# Lancement de l'entrainement et de l'évaluation.

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=3, patience=35)
lr_scheduler = LearningRateScheduler(lr_schedule)
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(x_train, y_train, batch_size=25, epochs=70, verbose=1, validation_split=0.2, callbacks=[es, lr_scheduler])
model.save('model.h5')
score=model.evaluate(x_test, y_test, verbose=1)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/70
# 19/19 [==============================] - 2s 52ms/step - loss: 0.0430 - accuracy: 0.9767 - val_loss: 0.2771 - val_accuracy: 0.9076 - lr: 1.0000e-04
# Epoch 2/70
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0451 - accuracy: 0.9789 - val_loss: 0.5859 - val_accuracy: 0.8571 - lr: 1.0000e-04
# Epoch 3/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0583 - accuracy: 0.9852 - val_loss: 0.2848 - val_accuracy: 0.9076 - lr: 1.0000e-04
# Epoch 4/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0465 - accuracy: 0.9852 - val_loss: 0.1128 - val_accuracy: 0.9748 - lr: 1.0000e-04
# Epoch 5/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0216 - accuracy: 0.9915 - val_loss: 0.1623 - val_accuracy: 0.9496 - lr: 1.0000e-04
# Epoch 6/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0505 - accuracy: 0.9810 - val_loss: 0.2575 - val_accuracy: 0.9328 - lr: 1.0000e-04
# Epoch 7/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0568 - accuracy: 0.9767 - val_loss: 0.3779 - val_accuracy: 0.9076 - lr: 1.0000e-04
# Epoch 8/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0478 - accuracy: 0.9789 - val_loss: 0.1033 - val_accuracy: 0.9664 - lr: 1.0000e-04
# Epoch 9/70
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0565 - accuracy: 0.9810 - val_loss: 0.0959 - val_accuracy: 0.9832 - lr: 1.0000e-04
# Epoch 10/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0505 - accuracy: 0.9810 - val_loss: 0.1259 - val_accuracy: 0.9748 - lr: 1.0000e-04
# Epoch 11/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0602 - accuracy: 0.9746 - val_loss: 0.3063 - val_accuracy: 0.8908 - lr: 1.0000e-04
# Epoch 12/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0619 - accuracy: 0.9810 - val_loss: 0.4376 - val_accuracy: 0.8908 - lr: 1.0000e-04
# Epoch 13/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0520 - accuracy: 0.9852 - val_loss: 0.3157 - val_accuracy: 0.9076 - lr: 1.0000e-04
# Epoch 14/70
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0321 - accuracy: 0.9852 - val_loss: 0.3690 - val_accuracy: 0.9076 - lr: 1.0000e-04
# Epoch 15/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0329 - accuracy: 0.9831 - val_loss: 0.4211 - val_accuracy: 0.8739 - lr: 1.0000e-04
# Epoch 16/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0538 - accuracy: 0.9767 - val_loss: 0.2099 - val_accuracy: 0.9412 - lr: 1.0000e-04
# Epoch 17/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0490 - accuracy: 0.9831 - val_loss: 0.2080 - val_accuracy: 0.9244 - lr: 1.0000e-04
# Epoch 18/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0315 - accuracy: 0.9915 - val_loss: 0.3338 - val_accuracy: 0.8824 - lr: 1.0000e-04
# Epoch 19/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0474 - accuracy: 0.9831 - val_loss: 0.3710 - val_accuracy: 0.8908 - lr: 1.0000e-04
# Epoch 20/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0392 - accuracy: 0.9810 - val_loss: 0.4657 - val_accuracy: 0.8571 - lr: 1.0000e-04
# Epoch 21/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0628 - accuracy: 0.9789 - val_loss: 0.3110 - val_accuracy: 0.8908 - lr: 1.0000e-04
# Epoch 22/70
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0341 - accuracy: 0.9894 - val_loss: 0.3383 - val_accuracy: 0.8739 - lr: 5.0000e-05
# Epoch 23/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.1114 - accuracy: 0.9683 - val_loss: 0.2891 - val_accuracy: 0.8824 - lr: 5.0000e-05
# Epoch 24/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0279 - accuracy: 0.9873 - val_loss: 0.2976 - val_accuracy: 0.8908 - lr: 5.0000e-05
# Epoch 25/70
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0457 - accuracy: 0.9831 - val_loss: 0.3006 - val_accuracy: 0.9076 - lr: 5.0000e-05
# Epoch 26/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0244 - accuracy: 0.9894 - val_loss: 0.2815 - val_accuracy: 0.9160 - lr: 5.0000e-05
# Epoch 27/70
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0432 - accuracy: 0.9810 - val_loss: 0.2898 - val_accuracy: 0.9160 - lr: 5.0000e-05
# Epoch 28/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0347 - accuracy: 0.9873 - val_loss: 0.2759 - val_accuracy: 0.9160 - lr: 5.0000e-05
# Epoch 29/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0279 - accuracy: 0.9915 - val_loss: 0.3189 - val_accuracy: 0.9160 - lr: 5.0000e-05
# Epoch 30/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0659 - accuracy: 0.9810 - val_loss: 0.3334 - val_accuracy: 0.9076 - lr: 5.0000e-05
# Epoch 31/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0166 - accuracy: 0.9915 - val_loss: 0.3812 - val_accuracy: 0.8908 - lr: 5.0000e-05
# Epoch 32/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0297 - accuracy: 0.9873 - val_loss: 0.4081 - val_accuracy: 0.8908 - lr: 1.0000e-05
# Epoch 33/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0157 - accuracy: 0.9958 - val_loss: 0.4153 - val_accuracy: 0.8992 - lr: 1.0000e-05
# Epoch 34/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0265 - accuracy: 0.9894 - val_loss: 0.4388 - val_accuracy: 0.8739 - lr: 1.0000e-05
# Epoch 35/70
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0282 - accuracy: 0.9894 - val_loss: 0.4569 - val_accuracy: 0.8655 - lr: 1.0000e-05
# Epoch 36/70
# 19/19 [==============================] - 4s 189ms/step - loss: 0.0192 - accuracy: 0.9915 - val_loss: 0.4835 - val_accuracy: 0.8655 - lr: 1.0000e-05
# Epoch 37/70
# 19/19 [==============================] - 4s 187ms/step - loss: 0.0226 - accuracy: 0.9937 - val_loss: 0.5126 - val_accuracy: 0.8655 - lr: 1.0000e-05
# Epoch 38/70
# 19/19 [==============================] - 4s 187ms/step - loss: 0.0127 - accuracy: 0.9958 - val_loss: 0.5296 - val_accuracy: 0.8571 - lr: 1.0000e-05
# Epoch 39/70
# 19/19 [==============================] - 4s 188ms/step - loss: 0.0123 - accuracy: 0.9937 - val_loss: 0.5231 - val_accuracy: 0.8571 - lr: 1.0000e-05
# Epoch 40/70
# 19/19 [==============================] - 4s 187ms/step - loss: 0.0115 - accuracy: 0.9958 - val_loss: 0.5169 - val_accuracy: 0.8571 - lr: 1.0000e-05
# Epoch 41/70
# 19/19 [==============================] - 4s 190ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.5237 - val_accuracy: 0.8571 - lr: 1.0000e-05
# Epoch 42/70
# 19/19 [==============================] - 4s 186ms/step - loss: 0.0144 - accuracy: 0.9958 - val_loss: 0.4972 - val_accuracy: 0.8571 - lr: 1.0000e-05
# Epoch 43/70
# 19/19 [==============================] - 4s 186ms/step - loss: 0.0161 - accuracy: 0.9937 - val_loss: 0.5037 - val_accuracy: 0.8571 - lr: 1.0000e-05
# Epoch 44/70
# 19/19 [==============================] - 4s 192ms/step - loss: 0.0209 - accuracy: 0.9937 - val_loss: 0.5286 - val_accuracy: 0.8571 - lr: 1.0000e-05
# Epoch 45/70
# 19/19 [==============================] - 4s 186ms/step - loss: 0.0174 - accuracy: 0.9937 - val_loss: 0.5300 - val_accuracy: 0.8571 - lr: 1.0000e-05
# Epoch 46/70
# 19/19 [==============================] - 4s 191ms/step - loss: 0.0100 - accuracy: 0.9958 - val_loss: 0.5219 - val_accuracy: 0.8571 - lr: 1.0000e-05
# Epoch 47/70
# 19/19 [==============================] - 4s 187ms/step - loss: 0.0233 - accuracy: 0.9915 - val_loss: 0.5059 - val_accuracy: 0.8655 - lr: 1.0000e-05
# Epoch 48/70
# 19/19 [==============================] - 4s 189ms/step - loss: 0.0151 - accuracy: 0.9958 - val_loss: 0.5273 - val_accuracy: 0.8655 - lr: 1.0000e-05
# Epoch 49/70
# 19/19 [==============================] - 4s 186ms/step - loss: 0.0130 - accuracy: 0.9937 - val_loss: 0.5501 - val_accuracy: 0.8655 - lr: 1.0000e-05
# Epoch 49: early stopping
# 6/6 [==============================] - 0s 69ms/step - loss: 1.2260 - accuracy: 0.7557
# Test loss: 1.2260233163833618
# Test accuracy: 0.7556818127632141

# %% [markdown]
# Nous arrivons à 75 pourcents ce qui est plutôt bon ! Lancement de la prédiction sur le corpus test.

# %%
y_pred_probs = model.predict(x_test)
#print(y_pred_probs)
y_pred = np.argmax(y_pred_probs, axis=1)
conf_mat = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', xticklabels=['malade', 'non_malade'], yticklabels=['malade', 'non_malade'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# 6/6 [==============================] - 0s 20ms/step

# %% [markdown]
# Enregistrement des mauvaises prédictions dans un fichier CSV

# %%
misclassified_data = []

for i in range(len(y_test)):
    if y_test[i] != y_pred[i]:
        actual_class = 'malade' if y_test[i] == 0 else 'non_malade'
        predicted_class = 'malade' if y_pred[i] == 0 else 'non_malade'
        image_name = os.path.basename(list_malade[i]) if i < len(list_malade) else os.path.basename(list_ok[i - len(list_malade)])
        
        misclassified_data.append([image_name, actual_class, predicted_class])

csv_file_path = 'mal_class_glides_spectro.csv'
header = ['Image Name', 'Actual Class', 'Predicted Class']

with open(csv_file_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(header)
    writer.writerows(misclassified_data)

print(f"c'est save :D {csv_file_path}")
import pandas as pd
res=pd.DataFrame(misclassified_data)
print(res)
# Out:
# c'est save :D mal_class_glides_spectro.csv
#                                                     0           1           2
# 0   spectrogram_SCA_F_AB30_2020_11_26_ModuleTransi...      malade  non_malade
# 1   spectrogram_SCA_F_AB30_2020_11_26_ModuleTransi...      malade  non_malade
# 2   spectrogram_SCA_F_AB31_2020_11_26_ModuleTransi...      malade  non_malade
# 3   spectrogram_SCA_F_AB31_2020_11_26_ModuleTransi...      malade  non_malade
# 4   spectrogram_SCA_H_AB25_2020_11_13_ModuleTransi...      malade  non_malade
# 5   spectrogram_SCA_H_AB25_2020_11_13_ModuleTransi...      malade  non_malade
# 6   spectrogram_SCA_H_AB25_2020_11_13_ModuleTransi...      malade  non_malade
# 7   spectrogram_SCA_H_AB25_2020_11_13_ModuleTransi...      malade  non_malade
# 8   spectrogram_SCA_H_AB36_2020_02_04_ModuleTransi...      malade  non_malade
# 9   spectrogram_SCA_H_AB36_2020_02_04_ModuleTransi...      malade  non_malade
# 10  spectrogram_SCA_H_AB36_2020_02_04_ModuleTransi...      malade  non_malade
# 11  spectrogram_SCA_H_AB36_2020_02_04_ModuleTransi...      malade  non_malade
# 12  spectrogram_SCA_H_AB36_2020_02_04_ModuleTransi...      malade  non_malade
# 13  spectrogram_SCA_H_AB36_2020_02_04_ModuleTransi...      malade  non_malade
# 14  spectrogram_SCA_H_AB36_2020_02_04_ModuleTransi...      malade  non_malade
# 15  spectrogram_SCA_H_AB36_2020_02_04_ModuleTransi...      malade  non_malade
# 16  spectrogram_SCA_H_AB37_2020_02_11_ModuleTransi...      malade  non_malade
# 17  spectrogram_SCA_H_AB37_2020_02_11_ModuleTransi...      malade  non_malade
# 18  spectrogram_SCA_H_AB37_2020_02_11_ModuleTransi...      malade  non_malade
# 19  spectrogram_SCA_H_AB37_2020_02_11_ModuleTransi...      malade  non_malade
# 20  spectrogram_SCA_H_AB37_2020_02_11_ModuleTransi...      malade  non_malade
# 21  spectrogram_SNC_F_AB1_2019_11_07_ModuleTransit...  non_malade      malade
# 22  spectrogram_SNC_F_AB1_2019_11_07_ModuleTransit...  non_malade      malade
# 23  spectrogram_SNC_F_AB1_2019_11_07_ModuleTransit...  non_malade      malade
# 24  spectrogram_SNC_F_AB1_2019_11_07_ModuleTransit...  non_malade      malade
# 25  spectrogram_SNC_F_AB1_2019_11_07_ModuleTransit...  non_malade      malade
# 26  spectrogram_SNC_F_AB1_2019_11_07_ModuleTransit...  non_malade      malade
# 27  spectrogram_SNC_F_AB1_2019_11_07_ModuleTransit...  non_malade      malade
# 28  spectrogram_SNC_F_EC16_2019_12_13_ModuleTransi...  non_malade      malade
# 29  spectrogram_SNC_F_EC16_2019_12_13_ModuleTransi...  non_malade      malade
# 30  spectrogram_SNC_H_AB3_2019_11_20_ModuleTransit...  non_malade      malade
# 31  spectrogram_SNC_H_AB3_2019_11_20_ModuleTransit...  non_malade      malade
# 32  spectrogram_SNC_H_AB3_2019_11_20_ModuleTransit...  non_malade      malade
# 33  spectrogram_SNC_H_AB3_2019_11_20_ModuleTransit...  non_malade      malade
# 34  spectrogram_SNC_H_AB3_2019_11_20_ModuleTransit...  non_malade      malade
# 35  spectrogram_SNC_H_AB3_2019_11_20_ModuleTransit...  non_malade      malade
# 36  spectrogram_SNC_H_AB3_2019_11_20_ModuleTransit...  non_malade      malade
# 37  spectrogram_SNC_H_AB3_2019_11_20_ModuleTransit...  non_malade      malade
# 38  spectrogram_SNC_H_AB3_2019_11_20_ModuleTransit...  non_malade      malade
# 39  spectrogram_SNC_H_AB3_2019_11_20_ModuleTransit...  non_malade      malade
# 40  spectrogram_SNC_H_AB3_2019_11_20_ModuleTransit...  non_malade      malade
# 41  spectrogram_SNC_H_AB7_2020_03_03_ModuleTransit...  non_malade      malade
# 42  spectrogram_SNC_H_AB7_2020_03_03_ModuleTransit...  non_malade      malade
# 43  spectrogram_SNC_H_AB7_2020_03_03_ModuleTransit...  non_malade      malade
# 44  spectrogram_SNC_H_AB7_2020_03_03_ModuleTransit...  non_malade      malade

# %% [markdown]
# Ce qui est intéressant ici c'est que le modèle classe les deux classes avec quasiment le même nombre d'erreur contrairement au CNN qui lui favorise les malades. Nous pouvons encore remarquer qu'il classe mal pour les malades les personnes avec une sévrité très basse. Neanmoins il classe aussi mal ceux qui sont moyennement sévère ce qui lui donne de moins bonnes performances que le CNN. L'input doit être sujet à plus de bruit et embrouiller le modèle lors de sa prise décision. Des graphiques montrant les les mauvaises prédictions sont disponibles sur le git.

# %% [markdown]
# Voici les essais moins concluants avec tanh et softmax.

# %%
model = Sequential()
model.add(Conv2D(512, kernel_size=(2, 2), activation='tanh', input_shape=(img_rows, img_cols, 1), padding='same'))
model.add(BatchNormalization())
value_top = 0
value_bottom = 0
value_left = 0
value_right = 0
model.add(ZeroPadding2D(padding=((value_top, value_bottom), (value_left, value_right))))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(256, (2, 2), activation='tanh', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, (2, 2), activation='tanh', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512, activation='tanh'))
model.add(BatchNormalization())
model.add(Dense(256, activation='tanh'))
model.add(BatchNormalization())
model.add(Dense(2, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 28, 28, 512)       2560
#
#  batch_normalization_5 (Bat  (None, 28, 28, 512)       2048
#  chNormalization)
#
#  zero_padding2d_1 (ZeroPadd  (None, 28, 28, 512)       0
#  ing2D)
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 512)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 256)       524544
#
#  batch_normalization_6 (Bat  (None, 14, 14, 256)       1024
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 256)         0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 128)         131200
#
#  batch_normalization_7 (Bat  (None, 7, 7, 128)         512
#  chNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 3, 3, 128)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 1152)              0
#
#  dropout_1 (Dropout)         (None, 1152)              0
#
#  dense_3 (Dense)             (None, 512)               590336
#
#  batch_normalization_8 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense_4 (Dense)             (None, 256)               131328
#
#  batch_normalization_9 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dense_5 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 1387138 (5.29 MB)
# Trainable params: 1383810 (5.28 MB)
# Non-trainable params: 3328 (13.00 KB)
# _________________________________________________________________

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=3, patience=35)
lr_scheduler = LearningRateScheduler(lr_schedule)
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(x_train, y_train, batch_size=25, epochs=70, verbose=1, validation_split=0.2, callbacks=[es, lr_scheduler])
model.save('model.h5')
score=model.evaluate(x_test, y_test, verbose=1)

print('Test loss:', score[0])
print('Test accuracy:', score[1])

y_pred_probs = model.predict(x_test)
#print(y_pred_probs)
y_pred = np.argmax(y_pred_probs, axis=1)
conf_mat = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', xticklabels=['malade', 'non_malade'], yticklabels=['malade', 'non_malade'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Epoch 1/70
# 19/19 [==============================] - 2s 55ms/step - loss: 0.1412 - accuracy: 0.9471 - val_loss: 0.2524 - val_accuracy: 0.9328 - lr: 1.0000e-04
# Epoch 2/70
# 19/19 [==============================] - 1s 46ms/step - loss: 0.1488 - accuracy: 0.9493 - val_loss: 0.1526 - val_accuracy: 0.9412 - lr: 1.0000e-04
# Epoch 3/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.1731 - accuracy: 0.9366 - val_loss: 0.4013 - val_accuracy: 0.8487 - lr: 1.0000e-04
# Epoch 4/70
# 19/19 [==============================] - 1s 46ms/step - loss: 0.1743 - accuracy: 0.9408 - val_loss: 0.1682 - val_accuracy: 0.9328 - lr: 1.0000e-04
# Epoch 5/70
# 19/19 [==============================] - 1s 46ms/step - loss: 0.1748 - accuracy: 0.9323 - val_loss: 0.1942 - val_accuracy: 0.9496 - lr: 1.0000e-04
# Epoch 6/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.1875 - accuracy: 0.9112 - val_loss: 0.1007 - val_accuracy: 0.9664 - lr: 1.0000e-04
# Epoch 7/70
# 19/19 [==============================] - 1s 45ms/step - loss: 0.1980 - accuracy: 0.9175 - val_loss: 0.1327 - val_accuracy: 0.9580 - lr: 1.0000e-04
# Epoch 8/70
# 19/19 [==============================] - 1s 46ms/step - loss: 0.2033 - accuracy: 0.9070 - val_loss: 0.0834 - val_accuracy: 0.9748 - lr: 1.0000e-04
# Epoch 9/70
# 19/19 [==============================] - 1s 45ms/step - loss: 0.2073 - accuracy: 0.9027 - val_loss: 0.2730 - val_accuracy: 0.8908 - lr: 1.0000e-04
# Epoch 10/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.1787 - accuracy: 0.9260 - val_loss: 0.1020 - val_accuracy: 0.9580 - lr: 1.0000e-04
# Epoch 11/70
# 19/19 [==============================] - 1s 45ms/step - loss: 0.1338 - accuracy: 0.9493 - val_loss: 0.3373 - val_accuracy: 0.8824 - lr: 1.0000e-04
# Epoch 12/70
# 19/19 [==============================] - 1s 45ms/step - loss: 0.1017 - accuracy: 0.9662 - val_loss: 0.1338 - val_accuracy: 0.9496 - lr: 1.0000e-04
# Epoch 13/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.1368 - accuracy: 0.9514 - val_loss: 0.8956 - val_accuracy: 0.6555 - lr: 1.0000e-04
# Epoch 14/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.1498 - accuracy: 0.9345 - val_loss: 0.3622 - val_accuracy: 0.8739 - lr: 1.0000e-04
# Epoch 15/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0976 - accuracy: 0.9683 - val_loss: 0.3149 - val_accuracy: 0.9076 - lr: 1.0000e-04
# Epoch 16/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.1249 - accuracy: 0.9493 - val_loss: 0.4306 - val_accuracy: 0.8571 - lr: 1.0000e-04
# Epoch 17/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.1065 - accuracy: 0.9619 - val_loss: 1.3725 - val_accuracy: 0.5882 - lr: 1.0000e-04
# Epoch 18/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.1372 - accuracy: 0.9471 - val_loss: 0.6589 - val_accuracy: 0.7983 - lr: 1.0000e-04
# Epoch 19/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0851 - accuracy: 0.9662 - val_loss: 0.0878 - val_accuracy: 0.9748 - lr: 1.0000e-04
# Epoch 20/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0876 - accuracy: 0.9704 - val_loss: 1.0421 - val_accuracy: 0.6723 - lr: 1.0000e-04
# Epoch 21/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0670 - accuracy: 0.9810 - val_loss: 1.1662 - val_accuracy: 0.6723 - lr: 1.0000e-04
# Epoch 22/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.1322 - accuracy: 0.9493 - val_loss: 0.3113 - val_accuracy: 0.8824 - lr: 5.0000e-05
# Epoch 23/70
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0826 - accuracy: 0.9725 - val_loss: 0.4301 - val_accuracy: 0.8067 - lr: 5.0000e-05
# Epoch 24/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0735 - accuracy: 0.9789 - val_loss: 0.5826 - val_accuracy: 0.7731 - lr: 5.0000e-05
# Epoch 25/70
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0426 - accuracy: 0.9873 - val_loss: 0.4805 - val_accuracy: 0.8151 - lr: 5.0000e-05
# Epoch 26/70
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0550 - accuracy: 0.9810 - val_loss: 0.2274 - val_accuracy: 0.9160 - lr: 5.0000e-05
# Epoch 27/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0475 - accuracy: 0.9810 - val_loss: 0.3982 - val_accuracy: 0.8151 - lr: 5.0000e-05
# Epoch 28/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0302 - accuracy: 0.9937 - val_loss: 0.3777 - val_accuracy: 0.8235 - lr: 5.0000e-05
# Epoch 29/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0500 - accuracy: 0.9831 - val_loss: 0.2093 - val_accuracy: 0.9244 - lr: 5.0000e-05
# Epoch 30/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0366 - accuracy: 0.9894 - val_loss: 0.1802 - val_accuracy: 0.9244 - lr: 5.0000e-05
# Epoch 31/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0290 - accuracy: 0.9894 - val_loss: 0.1843 - val_accuracy: 0.9412 - lr: 5.0000e-05
# Epoch 32/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0484 - accuracy: 0.9746 - val_loss: 0.2103 - val_accuracy: 0.9244 - lr: 1.0000e-05
# Epoch 33/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0331 - accuracy: 0.9937 - val_loss: 0.2720 - val_accuracy: 0.8908 - lr: 1.0000e-05
# Epoch 34/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0471 - accuracy: 0.9852 - val_loss: 0.3447 - val_accuracy: 0.8655 - lr: 1.0000e-05
# Epoch 35/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0184 - accuracy: 0.9937 - val_loss: 0.3921 - val_accuracy: 0.8487 - lr: 1.0000e-05
# Epoch 36/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0509 - accuracy: 0.9810 - val_loss: 0.3913 - val_accuracy: 0.8403 - lr: 1.0000e-05
# Epoch 37/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0367 - accuracy: 0.9873 - val_loss: 0.3131 - val_accuracy: 0.9076 - lr: 1.0000e-05
# Epoch 38/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0202 - accuracy: 0.9958 - val_loss: 0.2772 - val_accuracy: 0.8824 - lr: 1.0000e-05
# Epoch 39/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0285 - accuracy: 0.9915 - val_loss: 0.2833 - val_accuracy: 0.8824 - lr: 1.0000e-05
# Epoch 40/70
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0377 - accuracy: 0.9894 - val_loss: 0.2818 - val_accuracy: 0.8908 - lr: 1.0000e-05
# Epoch 41/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0420 - accuracy: 0.9831 - val_loss: 0.2750 - val_accuracy: 0.8824 - lr: 1.0000e-05
# Epoch 42/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0400 - accuracy: 0.9873 - val_loss: 0.2770 - val_accuracy: 0.9076 - lr: 1.0000e-05
# Epoch 43/70
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0342 - accuracy: 0.9873 - val_loss: 0.3372 - val_accuracy: 0.8655 - lr: 1.0000e-05
# Epoch 43: early stopping
# 1/6 [====>.........................] - ETA: 0s - loss: 0.4864 - accuracy: 0.9062
# C:\Users\Natou\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 6/6 [==============================] - 0s 21ms/step - loss: 1.5767 - accuracy: 0.7045
# Test loss: 1.5767054557800293
# Test accuracy: 0.7045454382896423
# 6/6 [==============================] - 0s 19ms/step

# %% [markdown]
# Les résultats sont inférieurs de 5 % avec ces paramètres.
